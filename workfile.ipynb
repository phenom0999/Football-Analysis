# %%
# %load_ext autoreload
# %autoreload 2
    
import helpers
import importlib

con = helpers.football()

con.load_data()
# Out:
# Loaded dataframes/players.csv into table players
# Loaded dataframes/matches.csv into table matches
# Loaded dataframes/events.csv into table events
# Loaded dataframes/teams.csv into table teams
# Loaded dataframes/positions.csv into table positions
# Loaded dataframes/event_tags.csv into table event_tags
# All files loaded into the database!

# %%
con.show_matches_table(5)
# Out:
#    match_id                 date  home_team  away_team  home_score  \
# 0   2500089  2018-05-13 14:00:00       1646       1659           1
# 1   2500090  2018-05-13 14:00:00       1628       1627           2
# 2   2500091  2018-05-13 14:00:00       1673       1609           0
# 3   2500092  2018-05-13 14:00:00       1612       1651           4
# 4   2500093  2018-05-13 14:00:00       1611       1644           1
#
#    away_score                                         label  \
# 0           2              Burnley - AFC Bournemouth, 1 - 2
# 1           0  Crystal Palace - West Bromwich Albion, 2 - 0
# 2           1            Huddersfield Town - Arsenal, 0 - 1
# 3           0     Liverpool - Brighton & Hove Albion, 4 - 0
# 4           0            Manchester United - Watford, 1 - 0
#
#                       venue  gameweek  winner_team_id
# 0                 Turf Moor        38            1659
# 1             Selhurst Park        38            1628
# ...

# %%
con.search_player_by_name("Salah", 5)
# Out:
#    weight firstName middleName     lastName  currentTeamId   birthDate  \
# 0      72  Mohamed        None  Salah Ghaly         1612.0  1992-06-15
#
#    height    wyId  foot      shortName  currentNationalTeamId
# 0     175  120353  left  Mohamed Salah                16129.0

# %%
con.goal_positions_of(120353)

# %%
con.test(120353)
# Out:
#     match_id                 date  home_team  away_team  home_score  \
# 0    2499727  2017-08-12 11:30:00       1644       1612           3
# 1    2499743  2017-08-27 15:00:00       1612       1609           4
# 2    2499763  2017-09-16 14:00:00       1612       1646           1
# 3    2499773  2017-09-23 16:30:00       1631       1612           2
# 4    2499807  2017-10-22 15:00:00       1624       1612           4
# 5    2499828  2017-11-04 17:30:00       1633       1612           1
# 6    2499828  2017-11-04 17:30:00       1633       1612           1
# 7    2499835  2017-11-18 15:00:00       1612       1619           3
# 8    2499835  2017-11-18 15:00:00       1612       1619           3
# 9    2499842  2017-11-25 17:30:00       1612       1610           1
# 10   2499858  2017-11-29 20:00:00       1639       1612           0
# 11   2499858  2017-11-29 20:00:00       1639       1612           0
# 12   2499872  2017-12-10 14:15:00       1612       1623           1
# ...
