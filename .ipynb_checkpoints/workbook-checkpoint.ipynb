# %%
# %load_ext autoreload
# %autoreload 2
    
import queries
import plots
import archived
import importlib


query = queries.queries()
plot = plots.plots()
archive = archived.archived()

query.load_data()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded dataframes/players.csv into table players
# Loaded dataframes/matches.csv into table matches
# Loaded dataframes/events.csv into table events
# Loaded dataframes/teams.csv into table teams
# Loaded dataframes/positions.csv into table positions
# Loaded dataframes/event_tags.csv into table event_tags
# All files loaded into the database!

# %%
query.show_players_table(5)
# Out:
#    weight          firstName middleName     lastName  currentTeamId  \
# 0      78              Harun       None        Tekin         4502.0
# 1      73             Malang       None         Sarr         3775.0
# 2      72               Over       None     Mandanda         3772.0
# 3      82  Alfred John Momar       None      N'Diaye          683.0
# 4      84           Ibrahima       None  Konat\u00e9         2975.0
#
#     birthDate  height    wyId   foot       shortName  currentNationalTeamId
# 0  1989-06-17     187   32777  right        H. Tekin                 4687.0
# 1  1999-01-23     182  393228   left         M. Sarr                 4423.0
# 2  1998-10-26     176  393230   None     O. Mandanda                    NaN
# 3  1990-03-06     187   32793  right      A. N'Diaye                19314.0
# 4  1999-05-25     192  393247  right  I. Konat\u00e9                    NaN

# %%
archive.find_matches_with_a`nomaly_goals_of_team(1611)
# Out:
#     match_id                 date  home_team  away_team  home_score  \
# 12   2499843  2017-11-25 15:00:00       1611       1651           1
#
#     away_score                                              label  \
# 12           0  Manchester United - Brighton & Hove Albion, 1 - 0
#
#            venue  gameweek  winner_team_id
# 12  Old Trafford        13            1611

# %%
query.get_match_by_event_id(190069551)

# %%
q = query.goal_positions_of_team(1625)


q[q["initialX"] > 95]
# Out:
#            id  initialX  initialY  finalX  finalY  playerId       shortName
# 10  188079625        97        54   100.0   100.0      8325  S. Ag\u00fcero
# 17  190069551       100        47     0.0     0.0     11066     R. Sterling
# 25  196255600        96        39     0.0     0.0    245364    L. San\u00e9
# 32  200656972        97        49   100.0   100.0     11066     R. Sterling
# 36  206732499        96        51   100.0   100.0    340386   Gabriel Jesus
# 42  211407478        99        52     0.0     0.0     70086     N. Otamendi
# 43  211407965        96        46     0.0     0.0      8317     David Silva
# 44  213395832        97        52   100.0   100.0      8317     David Silva
# 45  213396171        97        46   100.0   100.0     70086     N. Otamendi
# 48  214452502        97        44   100.0   100.0      8317     David Silva
# 52  215109780        99        56     0.0     0.0     11066     R. Sterling
# ...

# %%
plot.plot_goal_positions_of_team(1625, separate_players=True)

# %%
plot.plot_shots_vs_goals_of(14911)
