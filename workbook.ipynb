# %%
# %load_ext autoreload
# %autoreload 2
    
import queries
import plots
import archived
import importlib


query = queries.queries()
plot = plots.plots()
archive = archived.archived()

query.load_data()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loaded dataframes/players.csv into table players
# Loaded dataframes/matches.csv into table matches
# Loaded dataframes/events.csv into table events
# Loaded dataframes/teams.csv into table teams
# Loaded dataframes/positions.csv into table positions
# Loaded dataframes/event_tags.csv into table event_tags
# All files loaded into the database!

# %%
query.show_events_table(5)
# Out:
#    eventId subEventName  playerId  matchId eventName  teamId matchPeriod  \
# 0        8  Simple pass     25413  2499719      Pass    1609          1H
# 1        8    High pass    370224  2499719      Pass    1609          1H
# 2        8    Head pass      3319  2499719      Pass    1609          1H
# 3        8    Head pass    120339  2499719      Pass    1609          1H
# 4        8  Simple pass    167145  2499719      Pass    1609          1H
#
#     eventSec  subEventId         id
# 0   2.758649        85.0  177959171
# 1   4.946850        83.0  177959172
# 2   6.542188        82.0  177959173
# 3   8.143395        82.0  177959174
# 4  10.302366        85.0  177959175

# %%
query.search_team_by_name("liverpool", 5)
# Out:
#         city       name  wyId  officialName  type
# 0  Liverpool  Liverpool  1612  Liverpool FC  club

# %%
q = query.goal_positions_of_team(1624)
q[q['initialX'] < 80]
# Out:
#            id  initialX  initialY  finalX  finalY  playerId      shortName
# 3   185820216        79        85   100.0   100.0      8717        H. Kane
# 11  192168980        78        49   100.0   100.0      8717        H. Kane
# 37  218870556        69        50     0.0     0.0     14911  Son Heung-Min
# 46  226139027        76        40   100.0   100.0     61967     V. Wanyama
# 57  239137327        69        38   100.0   100.0        54     C. Eriksen
# 61  240759185        71         6   100.0   100.0        54     C. Eriksen

# %%
plot.plot_goal_positions_of_team(1624, separate_players=True)

# %%
query.get_match_by_event_id(240759185)
# Out:
#    match_id                 date  home_team  away_team  home_score  \
# 0   2500046  2018-04-07 14:00:00       1639       1624           1
#
#    away_score                                  label           venue  \
# 0           2  Stoke City - Tottenham Hotspur, 1 - 2  Bet365 Stadium
#
#    gameweek  winner_team_id
# 0        33            1624

# %%
plot.plot_shots_vs_goals_of(14911)
