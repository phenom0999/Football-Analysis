# %%
# %load_ext autoreload
# %autoreload 2
    
import queries
import plots
import archived
import importlib


query = queries.queries()
plot = plots.plots()
archive = archived.archived()

query.load_data()
# Out:
# Loaded dataframes/players.csv into table players
# Loaded dataframes/matches.csv into table matches
# Loaded dataframes/events.csv into table events
# Loaded dataframes/teams.csv into table teams
# Loaded dataframes/positions.csv into table positions
# Loaded dataframes/event_tags.csv into table event_tags
# All files loaded into the database!

# %%
query.show_events_table(5)
# Out:
#    eventId subEventName  playerId  matchId eventName  teamId matchPeriod  \
# 0        8  Simple pass     25413  2499719      Pass    1609          1H
# 1        8    High pass    370224  2499719      Pass    1609          1H
# 2        8    Head pass      3319  2499719      Pass    1609          1H
# 3        8    Head pass    120339  2499719      Pass    1609          1H
# 4        8  Simple pass    167145  2499719      Pass    1609          1H
#
#     eventSec  subEventId         id
# 0   2.758649        85.0  177959171
# 1   4.946850        83.0  177959172
# 2   6.542188        82.0  177959173
# 3   8.143395        82.0  177959174
# 4  10.302366        85.0  177959175

# %%
query.search_team_by_name("liverpool", 5)
# Out:
#         city       name  wyId  officialName  type
# 0  Liverpool  Liverpool  1612  Liverpool FC  club

# %%
q = query.goal_positions_of_team(1611)
q[q['initialX'] < 80]
# Out:
#            id  initialX  initialY  finalX  finalY  playerId      shortName
# 3   178495956        71        38     0.0     0.0      7936       P. Pogba
# 28  210187388        76        44   100.0   100.0      7939       A. Young
# 54  232587707        67        67   100.0   100.0     70122  N. Mati\u0107

# %%
plot.plot_goal_positions_of_team(1625, separate_players=True)

# %%
query.get_all_players_from_team(1625)
# Out:
#     weight                 firstName middleName  \
# 0       64                  Bernardo       None
# 1       78               Danilo Luiz       None
# 2       81  Nicol\u00e1s Hern\u00e1n       None
# 3       68                     Kevin       None
# 4       89                   Ederson       None
# 5       67             Fernando Luiz       None
# 6       83                      Kyle       None
# 7       85                   Vincent       None
# 8       67          David Josu\u00e9       None
# 9       70             Sergio Leonel       None
# 10      60                    Fabian       None
# 11      75                      John       None
# 12      69          Raheem Shaquille       None
# 13      67          Gabriel Fernando       None
# 14      80                \u0130lkay       None
# 15      85                  Benjamin       None
# 16      64                 Oleksandr       None
# 17      76                     Leroy       None
# ...

# %%
query.search_player_by_name('Fernandinho', 10)
# Out:
#    weight      firstName middleName lastName  currentTeamId   birthDate  \
# 0      67  Fernando Luiz       None     Rosa         1625.0  1985-05-04
#
#    height    wyId   foot    shortName  currentNationalTeamId
# 0     179  105339  right  Fernandinho                 6380.0

# %%
plot.plot_assist_path_of(38021)

# %%
query.show_events_table()
# Out:
#    eventId subEventName  playerId  matchId eventName  teamId matchPeriod  \
# 0        8  Simple pass     25413  2499719      Pass    1609          1H
# 1        8    High pass    370224  2499719      Pass    1609          1H
# 2        8    Head pass      3319  2499719      Pass    1609          1H
# 3        8    Head pass    120339  2499719      Pass    1609          1H
# 4        8  Simple pass    167145  2499719      Pass    1609          1H
#
#     eventSec  subEventId         id
# 0   2.758649        85.0  177959171
# 1   4.946850        83.0  177959172
# 2   6.542188        82.0  177959173
# 3   8.143395        82.0  177959174
# 4  10.302366        85.0  177959175

# %%
query.test()
# Out:
#      eventId subEventName  playerId  matchId eventName  teamId matchPeriod  \
# 0          8  Simple pass      8277  2499720      Pass    1625          1H
# 1          8  Simple pass      9380  2499720      Pass    1625          1H
# 2          8  Simple pass      8317  2499720      Pass    1625          1H
# 3          8  Simple pass      8317  2499720      Pass    1625          1H
# 4          8  Simple pass     70086  2499720      Pass    1625          1H
# ..       ...          ...       ...      ...       ...     ...         ...
# 518        8    Head pass    105339  2500095      Pass    1625          2H
# 519        8    Head pass      9380  2500095      Pass    1625          2H
# 520        8    Head pass     70083  2500095      Pass    1625          2H
# 521        8    Head pass    105339  2500095      Pass    1625          2H
# 522        8    Head pass      9380  2500095      Pass    1625          2H
#
#         eventSec  subEventId         id
# ...

# %%
query.search_team_by_name('totten')
# Out:
#      city               name  wyId          officialName  type
# 0  London  Tottenham Hotspur  1624  Tottenham Hotspur FC  club

# %%
t = query.test()
t.loc[0,1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[164], line 2
#       1 t = query.test()
# ----> 2 t.loc[0,1]
#
# ...
